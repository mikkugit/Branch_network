# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import random

# %%
col = []
for i in range(0,50000):
  col.append(i)

# %%
df = pd.DataFrame(columns=['sn','account_id','atm_id','withdraw'])
df['sn']=col

# %%
for i in df.index:
  df['account_id'][i]=str(random.randint(10000000000,99999999999))
  df['atm_id'][i] = random.randint(1,9999)
  df['withdraw'][i]=random.randint(50,2500)*10
# Out:
# <ipython-input-34-8242bdc23936>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['account_id'][i]=str(random.randint(10000000000,99999999999))
# <ipython-input-34-8242bdc23936>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['atm_id'][i] = random.randint(1,9999)
# <ipython-input-34-8242bdc23936>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['withdraw'][i]=random.randint(50,2500)*10

# %%
df
# Out:
#           sn   account_id atm_id withdraw
# 0          1  36730989396   3403    19480
# 1          2  51208224139   8249    14610
# 2          3  91493961050   4046     3210
# 3          4  85551163808   1957     8860
# 4          5  97420219832   9555    16500
# ...      ...          ...    ...      ...
# 49994  49995  90833871388   8504      570
# 49995  49996  48054691436   4013     6140
# 49996  49997  22925601614   7229    23010
# 49997  49998  53519223194   5330     2940
# 49998  49999  41180423021   8651     2610
#
# [49999 rows x 4 columns]

# %%
df.to_csv('/content/drive/MyDrive/atm/transaction.csv')

# %%
df['atm_id'].min()
# Out:
# 1
