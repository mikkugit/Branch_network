# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import random

# %%
def action_type(w):
  t=random.randint(-1,1)/10
  if(w<0.5+t):
    return 1
  if(w>0.8-t):
    return -1
  else:
    return 0

# %%
data=pd.read_csv('/content/drive/MyDrive/atm/transaction.csv')

# %%
col=[]
for i in range(1,10001):
  col.append(i)

# %%
df=pd.DataFrame(columns=['atm_id','location','s_amt','w_amt','bal','ration','action'])
df['atm_id']=col

# %%
data
# Out:
#        Unnamed: 0.1  Unnamed: 0     sn   account_id  atm_id  withdraw
# 0                 0           0      1  36730989396    3403     19480
# 1                 1           1      2  51208224139    8249     14610
# 2                 2           2      3  91493961050    4046      3210
# 3                 3           3      4  85551163808    1957      8860
# 4                 4           4      5  97420219832    9555     16500
# ...             ...         ...    ...          ...     ...       ...
# 49994         49994       49994  49995  90833871388    8504       570
# 49995         49995       49995  49996  48054691436    4013      6140
# 49996         49996       49996  49997  22925601614    7229     23010
# 49997         49997       49997  49998  53519223194    5330      2940
# 49998         49998       49998  49999  41180423021    8651      2610
#
# [49999 rows x 6 columns]

# %%
df
# Out:
#       atm_id location s_amt w_amt  bal ration action
# 0          1      NaN   NaN   NaN  NaN    NaN    NaN
# 1          2      NaN   NaN   NaN  NaN    NaN    NaN
# 2          3      NaN   NaN   NaN  NaN    NaN    NaN
# 3          4      NaN   NaN   NaN  NaN    NaN    NaN
# 4          5      NaN   NaN   NaN  NaN    NaN    NaN
# ...      ...      ...   ...   ...  ...    ...    ...
# 9995    9996      NaN   NaN   NaN  NaN    NaN    NaN
# 9996    9997      NaN   NaN   NaN  NaN    NaN    NaN
# 9997    9998      NaN   NaN   NaN  NaN    NaN    NaN
# 9998    9999      NaN   NaN   NaN  NaN    NaN    NaN
# 9999   10000      NaN   NaN   NaN  NaN    NaN    NaN
#
# [10000 rows x 7 columns]

# %%
locations_list =['Indiranagar','Rajajinagar','Malleswaram','Shivajinagar','Vasanth Nagar','CV Raman Nagar','Hoodi','Krishnarajapuram','Mahadevapura','Marathahalli','Varthur','Whitefield','HBR Layout','Banaswadi','Horamavu','Kalyan Nagar','Kammanahalli','Hebbal','Jalahalli']
l=len(locations_list)
for i in df.index:
  k=random.randint(0,l-1)
  df['location'][i]=locations_list[k]
  df['s_amt'][i]=random.randint(500,9000)*50
  df['w_amt'][i]=0
# Out:
# <ipython-input-184-e1e6b6060c0b>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['location'][i]=locations_list[k]
# <ipython-input-184-e1e6b6060c0b>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['s_amt'][i]=random.randint(500,9000)*50
# <ipython-input-184-e1e6b6060c0b>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['w_amt'][i]=0

# %%
for i in data.index:
  q=data['atm_id'][i]-1
  df['w_amt'][q]+=data['withdraw'][i]
# Out:
# <ipython-input-185-775cf634d3cb>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['w_amt'][q]+=data['withdraw'][i]

# %%
t=0
for i in df.index:
  df['bal']=df['s_amt']-df['w_amt']
  if(df['bal'][i]<0):
    t+=1
  df['ration'][i]=df['bal'][i]/df['s_amt'][i]
  df['action'][i]=action_type(df['ration'][i])

df
# Out:
# <ipython-input-186-e5f3b9a64035>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['ration'][i]=df['bal'][i]/df['s_amt'][i]
# <ipython-input-186-e5f3b9a64035>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['action'][i]=action_type(df['ration'][i])
#       atm_id       location   s_amt  w_amt     bal    ration action
# 0          1          Hoodi  154050  55450   98600  0.640052      0
# 1          2   Kalyan Nagar   73000   6880   66120  0.905753     -1
# 2          3     Whitefield  280400  54860  225540  0.804351     -1
# 3          4         Hebbal  315950  59970  255980  0.810191     -1
# ...

# %%
df['action'].value_counts()
# Out:
#  0    4056
# -1    3511
#  1    2433
# Name: action, dtype: int64

# %%
df.to_csv('/content/drive/MyDrive/atm/atm.csv')
